# %%
import torch
import cv2
import torch.nn as nn

import torchvision
import pandas as pd

from torchvision.transforms.functional import to_pil_image
import torchvision.transforms as T

from torchvision.io import read_image
from torchvision import tv_tensors
from torchvision.transforms.v2 import functional as F
from torchsummary import summary
from torchmetrics import Accuracy

from tqdm import tqdm
from torch.utils.data import DataLoader, Dataset
from torchvision import datasets, transforms, models
from torch.utils.tensorboard import SummaryWriter
import os
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.patches as patches
from PIL import Image
from sklearn.metrics import classification_report

# %%
print(torch.hub.get_dir())
torch.hub.set_dir("D:/models/torch/hub")
print(torch.hub.get_dir())
# Out:
# C:\Users\bapti/.cache\torch\hub
# D:/models/torch/hub

# %%
base_path = "D:/Programmation/IA/datas/fruit_classif/Fruit_dataset"
print(os.path.exists(base_path))
# Out:
# True

# %%
device = torch.device('cuda') if torch.cuda.is_available() else torch.device('cpu')
device
# Out:
# device(type='cuda')

# %%
class_name = []
with open(os.path.join(base_path, "classname.txt"), "r") as f:
    for line in f.readlines():
        class_name.append(line.replace("_", " ").replace("\n", ""))
class_name
# Out:
# ['oil palm',
#  'hog plum',
#  'apricot',
#  'sugar apple',
#  'rambutan',
#  'yellow plum',
#  'pineapple',
#  'dewberry',
#  'plumcot',
#  'ambarella',
#  'grenadilla',
#  'elderberry',
#  'barbadine',
#  'horned melon',
#  'chico',
#  'mock strawberry',
#  'cashew',
#  'finger lime',
#  'apple',
#  'eggplant',
#  'pawpaw',
#  'chokeberry',
#  'jamaica cherry',
#  'grapefruit',
#  'santol',
#  'chenet',
#  'salak',
#  'indian strawberry',
#  'cherimoya',
#  'otaheite apple',
#  'dragonfruit',
#  'raspberry',
#  'mangosteen',
#  'yali pear',
#  'taxus baccata',
#  'coconut',
#  'guava',
#  'black mullberry',
#  'durian',
#  'ackee',
#  'olive',
#  'mandarine',
#  'black berry',
#  'acerola',
#  'jaboticaba',
#  'fig',
#  'langsat',
#  'redcurrant',
#  'gooseberry',
#  'camu camu',
#  'barberry',
#  'rose hip',
#  'jalapeno',
#  'brazil nut',
#  'damson',
#  'acai',
#  'prikly pear',
#  'morinda',
#  'sea buckthorn',
#  'avocado',
#  'strawberry guava',
#  'jackfruit',
#  'greengage',
#  'cupuacu',
#  'longan',
#  'passion fruit',
#  'feijoa',
#  'betel nut',
#  'kaffir lime',
#  'sapodilla',
#  'cempedak',
#  'hawthorn',
#  'mango',
#  'malay apple',
#  'cranberry',
#  'jocote',
#  'cluster fig',
#  'corn kernel',
#  'kumquat',
#  'rose leaf bramble',
#  'jujube',
#  'grape',
#  'pea',
#  'papaya',
#  'bitter gourd',
#  'ugli fruit',
#  'jambul',
#  'mabolo',
#  'abiu',
#  'quince',
#  'custard apple',
#  'medlar',
#  'mountain soursop',
#  'banana',
#  'goumi',
#  'hard kiwi',
#  'pomegranate',
#  'white currant',
#  'lablab',
#  'emblic']

# %% [markdown]
# # Viz sample

# %%
df = pd.read_csv(os.path.join(base_path, "train.csv"))
df
# Out:
#                    image:FILE  category
# 0       train/oil_palm/57.jpg         0
# 1      train/oil_palm/881.jpg         0
# 2      train/oil_palm/450.jpg         0
# 3       train/oil_palm/28.jpg         0
# 4       train/oil_palm/62.jpg         0
# ...                       ...       ...
# 39995     train/emblic/86.jpg        99
# 39996     train/emblic/97.jpg        99
# 39997    train/emblic/149.jpg        99
# 39998    train/emblic/970.jpg        99
# 39999    train/emblic/874.jpg        99
#
# [40000 rows x 2 columns]

# %%
fig, axes = plt.subplots(1, 3, figsize=(12, 8))

indices = np.random.randint(0, len(df), 3)

for i, idx in enumerate(indices):
    img = cv2.imread(os.path.join(base_path, df.iloc[idx]["image:FILE"]))
    img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
    axes[i].set_title(f"{class_name[df.iloc[idx]['category']]}")
    axes[i].imshow(img)

# %% [markdown]
# # Dataloader class

# %%
def get_transform(train):
    transform_list = []
    transform_list.append(transforms.Resize(256))
    transform_list.append(transforms.CenterCrop(224))
    if train:
        transform_list.append(transforms.RandomHorizontalFlip())
    transform_list.append(transforms.ToTensor())
    transform_list.append(transforms.Normalize(mean=[0.485, 0.456, 0.406], std=[0.229, 0.224, 0.225]))

    return transforms.Compose(transform_list)

# %%
class CustomFruitDataset(Dataset):
    def __init__(self, csv_path, transforms=None):
        self.csv = pd.read_csv(csv_path)
        self.transforms = transforms

    def __len__(self):
        return len(self.csv)

    def __getitem__(self, idx):
        sample_row = self.csv.iloc[idx]
        label = sample_row["category"]
        
        image = Image.open(os.path.join(base_path, sample_row["image:FILE"])).convert('RGB')

        if self.transforms:
            image = self.transforms(image)

        return image, label

# %%
def denormalize(image_tensor):
    mean = torch.tensor([0.485, 0.456, 0.406]).view(3, 1, 1)
    std = torch.tensor([0.229, 0.224, 0.225]).view(3, 1, 1)
    image_tensor = image_tensor * std + mean
    return image_tensor.clamp(0, 1)

# %%
custom_ds = CustomFruitDataset(
    csv_path=os.path.join(base_path, "train.csv"),
    transforms=get_transform(train=True)
)

image, label = custom_ds[0]
image_denormalize = denormalize(image)
image_denormalize = image_denormalize.numpy().transpose((1, 2, 0))


fig, axes = plt.subplots(1, 2, figsize=(15, 8))

axes[0].imshow(image.permute(1, 2, 0))
axes[0].set_title("Before denormalization")

axes[1].imshow(image_denormalize)
axes[1].set_title("After denormalization")

fig.suptitle(f"Fruit name: {class_name[label]}")
plt.show()
# Out:
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [-2.1007793..2.5877128].

# %% [markdown]
# # Model and dataloader

# %%
def get_model(num_classes):
    model = torchvision.models.resnet50(weights="DEFAULT")
    try:
        model.fc = nn.Linear(model.fc.in_features, num_classes)
    except AttributeError:
        model.classifier[-1] = nn.Linear(model.classifier[-1].in_features, num_classes)
    return model

# %%
model = get_model(len(class_name)).to(device)
summary(model, (3, 256, 256))
# Out:
# ----------------------------------------------------------------
#         Layer (type)               Output Shape         Param #
# ================================================================
#             Conv2d-1         [-1, 64, 128, 128]           9,408
#        BatchNorm2d-2         [-1, 64, 128, 128]             128
#               ReLU-3         [-1, 64, 128, 128]               0
#          MaxPool2d-4           [-1, 64, 64, 64]               0
#             Conv2d-5           [-1, 64, 64, 64]           4,096
#        BatchNorm2d-6           [-1, 64, 64, 64]             128
#               ReLU-7           [-1, 64, 64, 64]               0
#             Conv2d-8           [-1, 64, 64, 64]          36,864
#        BatchNorm2d-9           [-1, 64, 64, 64]             128
#              ReLU-10           [-1, 64, 64, 64]               0
#            Conv2d-11          [-1, 256, 64, 64]          16,384
#       BatchNorm2d-12          [-1, 256, 64, 64]             512
#            Conv2d-13          [-1, 256, 64, 64]          16,384
#       BatchNorm2d-14          [-1, 256, 64, 64]             512
#              ReLU-15          [-1, 256, 64, 64]               0
#        Bottleneck-16          [-1, 256, 64, 64]               0
#            Conv2d-17           [-1, 64, 64, 64]          16,384
#       BatchNorm2d-18           [-1, 64, 64, 64]             128
#              ReLU-19           [-1, 64, 64, 64]               0
#            Conv2d-20           [-1, 64, 64, 64]          36,864
#       BatchNorm2d-21           [-1, 64, 64, 64]             128
#              ReLU-22           [-1, 64, 64, 64]               0
#            Conv2d-23          [-1, 256, 64, 64]          16,384
#       BatchNorm2d-24          [-1, 256, 64, 64]             512
#              ReLU-25          [-1, 256, 64, 64]               0
#        Bottleneck-26          [-1, 256, 64, 64]               0
#            Conv2d-27           [-1, 64, 64, 64]          16,384
#       BatchNorm2d-28           [-1, 64, 64, 64]             128
#              ReLU-29           [-1, 64, 64, 64]               0
#            Conv2d-30           [-1, 64, 64, 64]          36,864
#       BatchNorm2d-31           [-1, 64, 64, 64]             128
#              ReLU-32           [-1, 64, 64, 64]               0
#            Conv2d-33          [-1, 256, 64, 64]          16,384
#       BatchNorm2d-34          [-1, 256, 64, 64]             512
#              ReLU-35          [-1, 256, 64, 64]               0
#        Bottleneck-36          [-1, 256, 64, 64]               0
#            Conv2d-37          [-1, 128, 64, 64]          32,768
#       BatchNorm2d-38          [-1, 128, 64, 64]             256
#              ReLU-39          [-1, 128, 64, 64]               0
#            Conv2d-40          [-1, 128, 32, 32]         147,456
#       BatchNorm2d-41          [-1, 128, 32, 32]             256
#              ReLU-42          [-1, 128, 32, 32]               0
#            Conv2d-43          [-1, 512, 32, 32]          65,536
#       BatchNorm2d-44          [-1, 512, 32, 32]           1,024
#            Conv2d-45          [-1, 512, 32, 32]         131,072
#       BatchNorm2d-46          [-1, 512, 32, 32]           1,024
#              ReLU-47          [-1, 512, 32, 32]               0
#        Bottleneck-48          [-1, 512, 32, 32]               0
#            Conv2d-49          [-1, 128, 32, 32]          65,536
#       BatchNorm2d
[-1, 1024, 16, 16]         262,144
#      BatchNorm2d-128         [-1, 1024, 16, 16]           2,048
#             ReLU-129         [-1, 1024, 16, 16]               0
#       Bottleneck-130         [-1, 1024, 16, 16]               0
#           Conv2d-131          [-1, 256, 16, 16]         262,144
#      BatchNorm2d-132          [-1, 256, 16, 16]             512
#             ReLU-133          [-1, 256, 16, 16]               0
#           Conv2d-134          [-1, 256, 16, 16]         589,824
#      BatchNorm2d-135          [-1, 256, 16, 16]             512
#             ReLU-136          [-1, 256, 16, 16]               0
#           Conv2d-137         [-1, 1024, 16, 16]         262,144
#      BatchNorm2d-138         [-1, 1024, 16, 16]           2,048
#             ReLU-139         [-1, 1024, 16, 16]               0
#       Bottleneck-140         [-1, 1024, 16, 16]               0
#           Conv2d-141          [-1, 512, 16, 16]         524,288
#      BatchNorm2d-142          [-1, 512, 16, 16]           1,024
#             ReLU-143          [-1, 512, 16, 16]               0
#           Conv2d-144            [-1, 512, 8, 8]       2,359,296
#      BatchNorm2d-145            [-1, 512, 8, 8]           1,024
#             ReLU-146            [-1, 512, 8, 8]               0
#           Conv2d-147           [-1, 2048, 8, 8]       1,048,576
#      BatchNorm2d-148           [-1, 2048, 8, 8]           4,096
#           Conv2d-149           [-1, 2048, 8, 8]       2,097,152
#      BatchNorm2d-150           [-1, 2048, 8, 8]           4,096
#             ReLU-151           [-1, 2048, 8, 8]               0
#       Bottleneck-152           [-1, 2048, 8, 8]               0
#           Conv2d-153            [-1, 512, 8, 8]       1,048,576
#      BatchNorm2d-154            [-1, 512, 8, 8]           1,024
#             ReLU-155            [-1, 512, 8, 8]               0
#           Conv2d-156            [-1, 512, 8, 8]       2,359,296
#      BatchNorm2d-157            [-1, 512, 8, 8]           1,024
#             ReLU-158            [-1, 512, 8, 8]               0
#           Conv2d-159           [-1, 2048, 8, 8]       1,048,576
#      BatchNorm2d-160           [-1, 2048, 8, 8]           4,096
#             ReLU-161           [-1, 2048, 8, 8]               0
#       Bottleneck-162           [-1, 2048, 8, 8]               0
#           Conv2d-163            [-1, 512, 8, 8]       1,048,576
#      BatchNorm2d-164            [-1, 512, 8, 8]           1,024
#             ReLU-165            [-1, 512, 8, 8]               0
#           Conv2d-166            [-1, 512, 8, 8]       2,359,296
#      BatchNorm2d-167            [-1, 512, 8, 8]           1,024
#             ReLU-168            [-1, 512, 8, 8]               0
#           Conv2d-169           [-1, 2048, 8, 8]       1,048,576
#      BatchNorm2d-170           [-1, 2048, 8, 8]           4,096
#             ReLU-171           [-1, 2048, 8, 8]               0
#       Bottleneck-172           [-1, 2048, 8, 8]               0
# AdaptiveAvgPool2d-173           [-1, 2048, 1, 1]               0
#           Linear-174                  [-1, 100]         204,900
# ================================================================
# Total params: 23,712,932
# Trainable params: 23,712,932
# Non-trainable params: 0
# ----------------------------------------------------------------
# Input size (MB): 0.75
# Forward/backward pass size (MB): 374.27
# Params size (MB): 90.46
# Estimated Total Size (MB): 465.47
# ----------------------------------------------------------------

# %%
dataset_train = CustomFruitDataset(
    csv_path=os.path.join(base_path, "train.csv"),
    transforms=get_transform(train=True)
)
dataset_valid = CustomFruitDataset(
    csv_path=os.path.join(base_path, "val.csv"),
    transforms=get_transform(train=False)
)

# %%
train_data_loader = torch.utils.data.DataLoader(
    dataset_train,
    batch_size=64,
    shuffle=True,
)

val_data_loader = torch.utils.data.DataLoader(
    dataset_valid,
    batch_size=64,
    shuffle=False,
)

# %% [markdown]
# # Training

# %%
model = get_model(len(class_name)).to(device)
criterion = nn.CrossEntropyLoss()
optimizer = torch.optim.Adam(model.parameters(), lr=0.001)
num_epochs = 20
best_accuracy = 0.0
accuracy = Accuracy(task='multiclass', num_classes=len(class_name)).to(device)

# %%
for epoch in range(num_epochs):
    model.train()
    train_loss = 0.0
    train_loop = tqdm(train_data_loader, desc=f'Epoch {epoch}')
    for inputs, labels in train_loop:
        inputs, labels = inputs.to(device), labels.to(device)

        optimizer.zero_grad()
        outputs = model(inputs)
        loss = criterion(outputs, labels)
        loss.backward()
        optimizer.step()

        train_loss += loss.item()
        train_loop.set_postfix(loss=loss.item())

    train_loss /= len(train_data_loader)

    model.eval()
    val_loss = 0.0
    val_accuracy = 0.0
    val_loop = tqdm(val_data_loader, desc=f"Validation {epoch}")
    with torch.no_grad():
        for inputs, labels in val_loop:
            inputs, labels = inputs.to(device), labels.to(device)
            
            outputs = model(inputs)
            loss = criterion(outputs, labels)
            val_loss += loss.item()
            val_accuracy += accuracy(outputs, labels).item()

    val_loss /= len(val_data_loader)
    val_accuracy /= len(val_data_loader)

    print(f'Epoch {epoch}: Train Loss: {train_loss:.4f} | Val Loss: {val_loss:.4f} | Val Accuracy: {val_accuracy:.4f}')

    if val_accuracy > best_accuracy:
        best_accuracy = val_accuracy
        torch.save(model.state_dict(), 'best_model.pth')
        print(f"Modèle sauvegardé avec une précision de validation de {best_accuracy:.4f}")
# Out:
# Epoch 0: 100%|████████████████████████████████████████████████████████████| 625/625 [40:32<00:00,  3.89s/it, loss=1.28]
# Validation 0: 100%|████████████████████████████████████████████████████████████████████| 79/79 [02:21<00:00,  1.79s/it]
# Epoch 0: Train Loss: 1.5281 | Val Loss: 1.0837 | Val Accuracy: 0.6899
# Modèle sauvegardé avec une précision de validation de 0.6899
# Epoch 1: 100%|███████████████████████████████████████████████████████████| 625/625 [37:33<00:00,  3.60s/it, loss=0.825]
# Validation 1: 100%|████████████████████████████████████████████████████████████████████| 79/79 [01:57<00:00,  1.49s/it]
# Epoch 1: Train Loss: 0.8241 | Val Loss: 0.8777 | Val Accuracy: 0.7389
# Modèle sauvegardé avec une précision de validation de 0.7389
# Epoch 2: 100%|███████████████████████████████████████████████████████████| 625/625 [37:35<00:00,  3.61s/it, loss=0.604]
# Validation 2: 100%|████████████████████████████████████████████████████████████████████| 79/79 [01:57<00:00,  1.49s/it]
# Epoch 2: Train Loss: 0.6099 | Val Loss: 0.8284 | Val Accuracy: 0.7532
# Modèle sauvegardé avec une précision de validation de 0.7532
# Epoch 12: Train Loss: 0.1217 | Val Loss: 0.8522 | Val Accuracy: 0.7965
# Epoch 13: 100%|██████████████████████████████████████████████████████████| 625/625 [37:38<00:00,  3.61s/it, loss=0.187]
# Validation 13: 100%|███████████████████████████████████████████████████████████████████| 79/79 [01:57<00:00,  1.49s/it]
# Epoch 13: Train Loss: 0.1116 | Val Loss: 0.8747 | Val Accuracy: 0.8006
# Epoch 14:  53%|██████████████████████████████▋                           | 331/625 [20:03<17:48,  3.63s/it, loss=0.119]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[81], line 5
#       3 train_loss = 0.0
#       4 train_loop = tqdm(train_data_loader, desc=f'Epoch {epoch}')
# ----> 5 for inputs, labels in train_loop:
#       6     inputs, labels = inputs.to(device), labels.to(device)
#       8     optimizer.zero_grad()
#
# File D:\miniconda3\envs\torchenv\lib\site-packages\tqdm\std.py:1181, in tqdm.__iter__(self)
#    1178 time = self._time
#    1180 try:
# -> 1181     for obj in iterable:
#    1182         yield obj
#    1183         # Update and possibly print the progressbar.
#    1184         # Note: does not call self.update(1) for speed optimisation.
#
# File D:\miniconda3\envs\torchenv\lib\site-packages\torch\utils\data\dataloader.py:631, in _BaseDataLoaderIter.__next__(self)
#     628 if self._sampler_iter is None:
#     629     # TODO(https://github.com/pytorch/pytorch/issues/76750)
#     630     self._reset()  # type: ignore[call-arg]
# --> 631 data = self._next_data()
#     632 self._num_yielded += 1
#     633 if self._dataset_kind == _DatasetKind.Iterable and \
#     634         self._IterableDataset_len_called is not None and \
#     635         self._num_yielded > self._IterableDataset_len_called:
#
# File D:\miniconda3\envs\torchenv\lib\site-packages\torch\utils\data\dataloader.py:675, in _SingleProcessDataLoaderIter._next_data(self)
#     673 def _next_data(self):
#     674     index = self._next_index()  # may raise StopIteration
# --> 675     data = self._dataset_fetcher.fetch(index)  # may raise StopIteration
#     676     if self._pin_memory:
#     677         data = _utils.pin_memory.pin_memory(data, self._pin_memory_device)
#
# File D:\miniconda3\envs\torchenv\lib\site-packages\torch\utils\data\_utils\fetch.py:51, in _MapDatasetFetcher.fetch(self, possibly_batched_index)
#      49         data = self.dataset.__getitems__(possibly_batched_index)
#      50     else:
# ---> 51         data = [self.dataset[idx] for idx in possibly_batched_index]
#      52 else:
#      53     data = self.dataset[possibly_batched_index]
#
# File D:\miniconda3\envs\torchenv\lib\site-packages\torch\utils\data\_utils\fetch.py:51, in <listcomp>(.0)
#      49         data = self.dataset.__getitems__(possibly_batched_index)
#      50     else:
# ---> 51         data = [self.dataset[idx] for idx in possibly_batched_index]
#      52 else:
#      53     data = self.dataset[possibly_batched_index]
#
# Cell In[9], line 13, in CustomFruitDataset.__getitem__(self, idx)
#      10 sample_row = self.csv.iloc[idx]
#      11 label = sample_row["category"]
# ---> 13 image = Image.open(os.path.join(base_path, sample_row["image:FILE"])).convert('RGB')
#      15 if self.transforms:
#      16     image = self.transforms(image)
#
# File D:\miniconda3\envs\torchenv\lib\site-packages\PIL\Image.py:3247, in open(fp, mode, formats)
#    3244     filename = fp
#    3246 if filename:
# -> 3247     fp = builtins.open(filename, "rb")
#    3248     exclusive_fp = True
#    3250 try:
#
# KeyboardInterrupt:

# %% [markdown]
# # Test model

# %%
dataset_test = CustomFruitDataset(
    csv_path=os.path.join(base_path, "test.csv"),
    transforms=get_transform(train=False)
)

test_data_loader = torch.utils.data.DataLoader(
    dataset_valid,
    batch_size=64,
    shuffle=True,
)

# %%
best_model = get_model(len(class_name))
model.load_state_dict(torch.load('best_model.pth'))
model = model.to(device).eval()

# %%
true_labels = []
predictions = []

# Boucle de test
with torch.no_grad():
    test_loop = tqdm(test_data_loader, desc=f'Epoch {epoch}')
    for inputs, labels in test_loop:
        inputs, labels = inputs.to(device), labels.to(device)
        outputs = model(inputs)
        _, preds = torch.max(outputs, 1)

        true_labels.extend(labels.cpu().numpy())
        predictions.extend(preds.cpu().numpy())
# Out:
# Epoch 14:  47%|█████████████████████████████████▋                                      | 37/79 [05:17<46:12, 66.01s/it]

# %%
print(classification_report(true_labels, predictions, target_names=class_name)) # last 0.67
# Out:
#                    precision    recall  f1-score   support
#
#          oil palm       0.98      0.90      0.94        50
#          hog plum       0.45      0.50      0.47        50
#           apricot       0.84      0.52      0.64        50
#       sugar apple       0.73      0.38      0.50        50
#          rambutan       0.98      1.00      0.99        50
#       yellow plum       0.83      0.60      0.70        50
#         pineapple       0.94      1.00      0.97        50
#          dewberry       0.82      0.56      0.67        50
#           plumcot       0.47      0.80      0.59        50
#         ambarella       0.72      0.46      0.56        50
#        grenadilla       0.72      0.58      0.64        50
#        elderberry       0.72      0.88      0.79        50
#         barbadine       0.63      0.76      0.69        50
#      horned melon       0.93      1.00      0.96        50
#             chico       0.63      0.44      0.52        50
#   mock strawberry       0.62      0.42      0.50        50
#            cashew       0.70      0.94      0.80        50
#       finger lime       0.96      0.92      0.94        50
#             apple       0.90      0.70      0.79        50
#          eggplant       1.00      0.94      0.97        50
#            pawpaw       0.49      0.74      0.59        50
#        chokeberry       0.98      0.86      0.91        50
#    jamaica cherry       0.76      0.76      0.76        50
#        grapefruit       0.76      0.74      0.75        50
#            santol       0.95      0.80      0.87        50
#            chenet       0.96      0.86      0.91        50
#             salak       0.79      0.92      0.85        50
# indian strawberry       0.49      0.66      0.56        50
#         cherimoya       0.73      0.64      0.68        50
#    otaheite apple       0.71      0.78      0.74        50
#       dragonfruit       0.98      0.88      0.93        50
#         raspberry       0.89      0.80      0.84        50
#        mangosteen       0.88      0.84      0.86        50
#         yali pear       0.95      0.84      0.89        50
#     taxus baccata       1.00      0.96      0.98        50
#           coconut       0.90      0.70      0.79        50
#             guava       0.58      0.78      0.67        50
#   black mullberry       0.85      0.82      0.84        50
#            durian       0.96      1.00      0.98        50
#             ackee       0.96      0.92      0.94        50
#             olive       0.91      0.82      0.86        50
#         mandarine       0.91      0.58      0.71        50
#       black berry       0.67      0.74      0.70        50
#           acerola       0.72      0.88      0.79        50
#        jaboticaba       0.85      0.94      0.90        50
#               fig       0.94      0.90      0.92        50
#           langsat       0.70      0.92      0.79        50
#        redcurrant       0.87      0.94      0.90        50
#        gooseberry       0.88      0.72      0.79        50
#         camu camu       0.96      0.94      0.95        50
#          barberry       0.95      0.76      0.84        50
#          rose hip       0.89      0.68      0.77        50
#          jalapeno       0.94      0.92      0.93        50
#        brazil nut       0.90      0.90      0.90        50
#            damson       0.89      0.78      0.83        50
#              acai       0.75      0.84      0.79        50
#       prikly pear       0.88      0.86      0.87        50
#           morinda       0.98      0.98      0.98        50
#     sea buckthorn       0.92      0.98      0.95        50
#           avocado       0.93      0.80      0.86        50
#  strawberry guava       0.79      0.84      0.82        50
#         jackfruit       0.82      0.82      0.82        50
#         greengage       0.72      0.76      0.74        50
#           cupuacu       0.91      0.82      0.86        50
#            longan       0.90      0.88      0.89        50
#     passion fruit       0.95      0.74      0.83        50
#            feijoa       0.86      0.86      0.86        50
#         betel nut       0.86      0.76      0.81        50
#       kaffir lime       0.96      0.88      0.92        50
#         sapodilla       0.63      0.74      0.68        50
#          cempedak       0.82      0.72      0.77        50
#          hawthorn       0.83      0.80      0.82        50
#             mango       0.77      0.60      0.67        50
#       malay apple       0.73      0.82      0.77        50
#         cranberry       0.75      0.78      0.76        50
#            jocote       0.53      0.74      0.62        50
#       cluster fig       0.72      0.72      0.72        50
#       corn kernel       0.96      0.94      0.95        50
#           kumquat       0.62      0.62      0.62        50
# rose leaf bramble       0.75      0.80      0.78        50
#            jujube       0.62      0.72      0.67        50
#             grape       0.85      0.88      0.86        50
#               pea       0.90      0.94      0.92        50
#            papaya       0.70      0.60      0.65        50
#      bitter gourd       0.96      0.90      0.93        50
#        ugli fruit       0.72      0.96      0.82        50
#            jambul       0.92      0.90      0.91        50
#            mabolo       0.89      0.82      0.85        50
#              abiu       0.68      0.94      0.79        50
#            quince       0.88      0.84      0.86        50
#     custard apple       0.42      0.78      0.55        50
#            medlar       0.90      0.92      0.91        50
#  mountain soursop       0.85      0.68      0.76        50
#            banana       0.96      0.90      0.93        50
#             goumi       0.93      0.80      0.86        50
#         hard kiwi       0.80      0.88      0.84        50
#       pomegranate       0.80      0.96      0.87        50
#     white currant       0.98      0.96      0.97        50
#            lablab       0.89      0.98      0.93        50
#            emblic       0.84      0.84      0.84        50
#
#          accuracy                           0.80      5000
#         macro avg       0.82      0.80      0.80      5000
#      weighted avg       0.82      0.80      0.80      5000

# %%
# torch.save(model.state_dict(), 'best_model_resnet50.pth') with ~80%
